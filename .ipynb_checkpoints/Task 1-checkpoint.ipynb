# %%
#111-2 practice 1

import pandas as pd

#read csv file
score = pd.read_csv("score.csv")
score
# Out:
#    student id  HW 1  HW 2  HW 3  HW 4  HW 5  project  total
# 0   41071120H  15.0  15.0    15    15    15       93     98
# 1   41071103H  15.0  15.0    15    15    15       93     98
# 2   41071117H  15.0  15.0    15    15    15       92     98
# 3   41071134H  15.0  15.0    15    15    15       92     98
# 4   41171212H  15.0  15.0    15    15    15       92     98
# 5   41071102H  15.0  15.0    15    15    15       92     98
# 6   41071122H  15.0  15.0    15    15    15       91     98
# 7   41071105H  15.0  15.0    15    15    15       91     98
# 8   41071213H  15.0  15.0    15    15    15       91     98
# 9   41071110h  15.0  15.0    15    15    15       89     97
# 10  41071205H  15.0  15.0    15    15    15       89     97
# 11  41071119H  15.0  15.0    15    15    15       89     97
# 12  41071118H  15.0  15.0    15    15    15       89     97
# 13  60971037H  15.0  15.0    15    15    15       88     97
# 14  91199015Y  15.0  15.0    15    15    15       88     97
# ...

# %%
alldata1 = list(score['student id'])
alldata1
# Out:
# ['41071120H',
#  '41071103H',
#  '41071117H',
#  '41071134H',
#  '41171212H',
#  '41071102H',
#  '41071122H',
#  '41071105H',
#  '41071213H',
#  '41071110h',
#  '41071205H',
#  '41071119H',
#  '41071118H',
#  '60971037H',
#  '91199015Y',
#  '41071133h',
#  '41071227H',
#  '41071107H',
#  '40971203H',
#  '40971117H',
#  '40923213L',
#  '40923117L',
#  '40971125H',
#  '41071108h',
#  '41071104H',
#  '41071111H',
#  '41071127H',
#  '40971122h',
#  '41071115H',
#  '40971116H',
#  '41071211H',
#  '41071229H',
#  '41071124H',
#  '61071009H',
#  '40871117H',
#  '40971225H',
#  '41071132H',
#  '41071101H',
#  '40971130H',
#  '41071109h',
#  '40971229H',
#  '41071129H',
#  '41071112H',
#  '41071106H']

# %%
A1 = {'a', 'b', 'c', 'd', 'e'}
A2 = {'1', '2', '3', 'a', 'b'}

print (A1&A2)
print (A1|A2)
print (A1-A2)
print ((A1|A2)-(A1&A2))
# Out:
# {'b', 'a'}
# {'2', 'c', 'e', 'd', 'b', 'a', '3', '1'}
# {'e', 'c', 'd'}
# {'2', 'c', 'e', 'd', '3', '1'}
