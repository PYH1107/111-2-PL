# %%
import requests
from bs4 import BeautifulSoup

web = requests.get("https://udn.com/news/cate/2/7225")
content = BeautifulSoup(web.text, "html.parser")
allTitle = content.select(".story-list__text h2")
title_list = []

for i in allTitle[3:]:
    title_list.append(i.text[1:-1])

print(title_list)
# Out:
# ['在烏克蘭舉起中華民國旗！台灣志願兵的戰爭啟示錄', '烏南水壩被炸／第聶伯河岸水位上漲 俄烏地雷恐位移', '土耳其女星奪影后稱「為女性困境而演」 保守勢力轟：可悲西方奴隸', '入北約起手式？傳瑞典法院批准土耳其引渡要求', '土耳其「政媒一體」，讓選民變成順民？', '必須動手術！86歲教宗方濟各身體出狀況 術後將住院數日', '日本鋒面滯留防激烈降雨 颱風谷超恐接力影響', '部落客嗨摸泰國大地女神「胸部」！被罵不尊重神明 1關鍵讓兩派人戰翻', '疑不滿被店員叫「大叔」！馬國男餐廳內抓狂 4歲男童慘被誤傷', '摩納哥前1%富豪資產 八位數美元起跳', '紅酒燉肉指數 反映法國食材成本飆高', '倫敦以外每月房租 漲破1,000英鎊', '「搖下車窗vs開空調」何者省油？實測結果破迷思 關鍵在1動作', '出軌上百次、家有不明丁字褲 妻奪布娃娃丈夫「男子氣概」：他對我撒謊', '影／跑步機壞壞！女運動跌倒竟被「脫褲子」 超糗畫面全被錄', '影／男友去超市買香蕉「靠1招省錢」 全場傻眼勸分手：好丟臉', '「吹哨者」爆料美國數十年來一直在回收UFO 甚至擁有「完整」飛行器', '一天生出貝佐斯旁的奧斯卡座位！他出身平凡如何成為全球0.003％富人最強買手？', 'ChatGPT爆紅後...OpenAI是否打算上市？執行長回應了', '這不是愛麗兒！「小美人魚」中、韓票房慘遭滑鐵盧 種族議題續延燒', '風吹草低不只見牛羊 馬斯克與這國商討電動車投資事宜', '憂經濟前景 近三成澳洲企業計劃離開中國市場', '想找媽媽！美國10歲男童偷開車上路 警方急追趕逮人', '畢業典禮傳槍響！美國高中槍擊案釀2死5傷 19歲槍手被捕', '嚴懲芬太尼毒販法案挫敗 加州家長聯盟訴諸公投', '心腹變對手！克利斯蒂宣布參選總統 鬥垮川普拯救共和黨', '「這裡像鬼城」舊金山治安急遽惡化！ 居民、企業往外逃']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import jieba

# 將標題列表轉換為文字串接
text = ' '.join(title_list)

# 中文分詞
seg_list = jieba.cut(text, cut_all=False)
seg_list = list(seg_list)

# 設定字體路徑
font_path = 'C:/Windows/Fonts/msjh.ttc'


# 使用 WordCloud 產生文字雲
wordcloud = WordCloud(background_color='white', width=800, height=600, font_path='msjh.ttc', max_words=100, max_font_size=100).generate(text)

# 顯示文字雲
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\maypa\AppData\Local\Temp\jieba.cache
# Loading model cost 0.630 seconds.
# Prefix dict has been built successfully.
